# %%
import numpy as np
import pandas as pd
import re

# %%
X = pd.read_csv("just tacos and burritos.csv")

# %%
X.head(5)
# Out:
#                      id                   address  \
# 0  AVwc__cikufWRAb51QjV         610 Commercial St
# 1  AVwc__cikufWRAb51QjV         610 Commercial St
# 2  AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3  AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4  AVwc__WtByjofQCxkdkR             8495 W 3rd St
#
#                                           categories         city country  \
# 0  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison      US
# 1  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison      US
# 2       Golf Course, American Restaurant, and Resort    Patterson      US
# 3                               Fast Food Restaurant     Longmont      US
# 4  Mexican Restaurant Mid-City West,Mexican Resta...  Los Angeles      US
#
#                       cuisines             dateAdded           dateUpdated  \
# 0  Restaurant Delivery Service  2016-03-02T11:49:34Z  2017-02-01T18:04:44Z
# ...

# %%
set(X['country'])
# Out:
# {'US'}

# %%
len(set(X['cuisines'])) #1589
# There is nan
# Out:
# 1589

# %%
len(set(X['categories'])) #8488
# There is no NAN
# Out:
# 8488

# %%
len(set(X['city'])) #3601
# Out:
# 3601

# %%
len(set(X['dateAdded'])) #17965
# Out:
# 17965

# %%
type(X['categories'])
filtered_category = X['categories'].str.contains('Mexican Restaurant', regex=True)
filtered_category.value_counts()

X['cuisines'][filtered_category].isna().value_counts()
# Out:
# True     22567
# False    16241
# Name: cuisines, dtype: int64

# %%
X['categories'].value_counts()
# Out:
# Mexican Restaurant                                                                                                15094
# Restaurant                                                                                                         4451
# Tex-Mex Restaurant                                                                                                 2757
# Fast Food Restaurant                                                                                               1783
# American Restaurant                                                                                                1338
#                                                                                                                   ...
# Dive Bar,American Restaurant,Bar,Dive Bar, American Restaurant, and Bar                                               1
# Seafood Restaurant,Food and Beverage,Fast Food Restaurant,Fast Food Restaurant and Seafood Restaurant                 1
# ...

# %%
filtered_taco = X['menus.name'].str.contains('Taco', flags=re.IGNORECASE, regex=True)
filtered_burrito = X['menus.name'].str.contains('Burrito', flags=re.IGNORECASE, regex=True)
X['Taco'] = filtered_taco
X['Burrito'] = filtered_burrito

# %%
print(filtered_taco.value_counts())
print(filtered_burrito.value_counts())
# Out:
# True     41849
# False    35411
# Name: menus.name, dtype: int64
# False    41514
# True     35746
# Name: menus.name, dtype: int64

# %%
X['menu_type'] = 'Unknown'
X['menu_type'] = np.where(X['Taco'] == True, 'Taco', X['menu_type'])
X['menu_type'] = np.where(X['Burrito'] == True, 'Burrito', X['menu_type'])

# %%
X['menu_type']
# Out:
# 0           Taco
# 1           Taco
# 2        Burrito
# 3        Burrito
# 4           Taco
#           ...
# 77255    Burrito
# 77256    Burrito
# 77257       Taco
# 77258    Burrito
# 77259    Burrito
# Name: menu_type, Length: 77260, dtype: object

# %%
X.drop(['Taco', 'Burrito'], axis=1)
# Out:
#                          id                   address  \
# 0      AVwc__cikufWRAb51QjV         610 Commercial St
# 1      AVwc__cikufWRAb51QjV         610 Commercial St
# 2      AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3      AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4      AVwc__WtByjofQCxkdkR             8495 W 3rd St
# ...                     ...                       ...
# 77255  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77256  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77257  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77258  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77259  AVzRLlQNLD2H7whiWdH_             3919 24th St.
#
#                                               categories           city  \
# 0      Restaurant Delivery Service,Restaurants,Pizza,...       Atchison
# 1      Restaurant Delivery Service,Restaurants,Pizza,...       Atchison
# 2           Golf Course, American Restaurant, and Resort      Patterson
# ...

# %%
X.to_csv('tacos-burritos-vs-city.csv')

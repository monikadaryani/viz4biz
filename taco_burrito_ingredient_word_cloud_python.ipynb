# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
import re

# %%
data_frame = pd.read_csv('just tacos and burritos.csv')
data_frame = data_frame[data_frame['menus.name'].str.contains("Taco",flags=re.IGNORECASE,regex=True)]
data_frame = data_frame['menus.description']
data_frame = data_frame.dropna()
data_frame.head()
# Out:
# 1    Beef, onion, cheddar cheese, lettuce,  refried...
# 4    Wahoo, avocado, cabbage, pico de gallo  and av...
# 5    Hand breaded fried wahoo, topped with   cabbag...
# 6    Any combination of two original baja or americ...
# 7    Grilled corn tortillas with salsa, onions and ...
# Name: menus.description, dtype: object

# %%
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in data_frame: 
      
    # typecaste each val to string 
    val = str(val).lower()
    val = val.replace('spicy','spicy,')
    # split the value 
    tokens = val.split(',')
    
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('taco.png')
plt.show()

# %%
data_frame = pd.read_csv('just tacos and burritos.csv')
data_frame = data_frame[data_frame['menus.name'].str.contains("Burrito",flags=re.IGNORECASE,regex=True)]
data_frame = data_frame['menus.description']
data_frame = data_frame.dropna()
data_frame.head()
# Out:
# 2     Beef barbacoa or chicken, spanish rice, pico d...
# 9                           Cabo style or caesar style.
# 10    Black beans, rice, jack cheese, onions, cilant...
# 12    Black or pinto beans, rice, cilantro and onion...
# 13    Melted jack cheese, guacamole and pico de gall...
# Name: menus.description, dtype: object

# %%
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in data_frame: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split(',')
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig('burrito.png')  
plt.show()
